# %%
import pandas as pd
import numpy as np
import regex as re

# %%
df = pd.read_csv('gubernatorial_bios.csv')

# %%
import pandas as pd
import numpy as np

# Ensure birth_date is datetime
df['birth_date'] = pd.to_datetime(df['birth_date'], errors='coerce')

# Only process rows where age_at_start is not NA
mask = df['age_at_start'].notna() & df['birth_date'].notna() & df['first_year'].notna()

# Extract month, day, last two digits of year
df['month'] = df['birth_date'].dt.month
df['day'] = df['birth_date'].dt.day
df['yy'] = df['birth_date'].dt.year % 100

# Compute target year
df['target'] = df['first_year'] - df['age_at_start']
df['base_century'] = (df['target'] // 100) * 100

# Candidate years
df['cand1'] = df['base_century'] - 100 + df['yy']
df['cand2'] = df['base_century'] + df['yy']
df['cand3'] = df['base_century'] + 100 + df['yy']

# Absolute differences
df['diff1'] = abs(df['cand1'] - df['target'])
df['diff2'] = abs(df['cand2'] - df['target'])
df['diff3'] = abs(df['cand3'] - df['target'])

# Choose closest candidate safely using np.select
conditions = [
    (df['diff1'] <= df[['diff1','diff2','diff3']].min(axis=1)),
    (df['diff2'] <= df[['diff1','diff2','diff3']].min(axis=1)),
    (df['diff3'] <= df[['diff1','diff2','diff3']].min(axis=1))
]
choices = [df['cand1'], df['cand2'], df['cand3']]
df['chosen_year'] = np.select(conditions, choices, default=np.nan)

# Rebuild birth_date only for rows with age_at_start
df['birth_date'] = np.where(
    mask,
    pd.to_datetime(dict(year=df['chosen_year'], month=df['month'], day=df['day']), errors='coerce'),
    df['birth_date']
)

# Drop helper columns
df.drop(columns=['month','day','yy','target','base_century','cand1','cand2','cand3','diff1','diff2','diff3','chosen_year'], inplace=True)

# %%
df[df['birth_date'].isna()]
# Out:
#       Unnamed: 0 state_territory                 governor       party  \
# 2260        2261        Virginia  Andrew Jackson Montague  Democratic
#
#       first_year years_in_office  \
# 2260        1902     1902 - 1906
#
#                                                  school birth_state_territory  \
# 2260  Richmond College, University of Virginia Law S...              Virginia
#
#      spouse birth_date                                           bio_text  \
# 2260    NaN        NaT  ANDREW JACKSON MONTAGUE was born in Lynchburg,...
#
#       college_attendance  ivy_attendance  lawyer  military_service  \
# 2260                   1               0       1                 0
#
#       age_at_start gender  born_in_state_territory  intl_born  \
# 2260           NaN   male                        1          0
#
#      intl_born_details
# 2260               NaN

# %%
# mapping = {'Luis Muñoz Marín': '1898-02-18',
#            'Kenneth Mapp' : '1955-11-02',
#            'John de Jongh, Jr.' : '1957-11-13',
#            'Charles W. Turnbull' : '1935-02-05',
#            'Roy Lester Schneider': '1939-05-13',
#            'Alexander A. Farrelly': '1923-12-29',
#            'Juan Francisco Luis': '1940-07-10',
#            'Cyril Emmanuel King': '1921-04-07',
#            'Melvin Herbert Evans': '1917-08-07',
#            'Ralph M. Paiewonsky': '1907-11-09'}

# df['birth_date'] = df['birth_date'].fillna(df['governor'].map(mapping))

# %%
df[df['age_at_start'].isna()]
# Out:
#       Unnamed: 0 state_territory                    governor  \
# 78            79         Alabama       William James Samford
# 436          437         Florida      Henry Laurens Mitchell
# 794          795        Kentucky                  John Adair
# 812          813       Louisiana           Sam Houston Jones
# 1067        1068        Michigan      Luren Dudley Dickinson
# 1073        1074        Michigan  Alexander Joseph Groesbeck
# 1355        1356   New Hampshire             Walter Peterson
# 1544        1545        New York          David Bennett Hill
# 1877        1878    Rhode Island                 Henry Smith
# 1888        1889    Rhode Island      George Peabody Wetmore
# 1987        1988  South Carolina          James Jr. Hamilton
# 2080        2081       Tennessee           William Trousdale
# 2178        2179         Vermont            Charles W. Gates
# 2211        2212         Vermont     John Staniford Robinson
# 2260        2261        Virginia     Andrew Jackson Montague
# 2400        2401       Wisconsin            Lucius Fairchild
# 2423        2424         Wyoming        Lester Calloway Hunt
#
#                       party  first_year years_in_office  \
# 78               Democratic        1900     1900 - 1901
# 436              Democratic        1893     1893 - 1897
# 794   Democratic-Republican        1820     1820 - 1824
# 812              Democratic        1940     1940 - 1944
# 1067             Republican        1939     1939 - 1941
# 1073             Republican        1921     1921 - 1927
# 1355             Republican        1969     1969 - 1973
# 1544             Democratic        1885     1885 - 1892
# 1877                    NaN        1806     1905 - 1806
# 1888             Republican        1885     1885 - 1887
# 1987             Democratic        1830     1830 - 1832
# 2080             Democratic        1849     1849 - 1851
# 2178             Republican        1915     1915 - 1917
# 2211             Democratic        1853     1853 - 1854
# 2260             Democratic        1902     1902 - 1906
# 2400             Republican        1866     1866 - 1872
# 2423             Democratic        1943     1943 - 1949
#
#                                                  school  \
# 78    East Alabama Male College (now Auburn Universi...
# 436   system, moved to Tampa and studied law, and in...
# 794   system of Charlotte, North Carolina. Adair had...
# 812                          Louisiana State University
# 1067  in Michigan. Dickinson established an extensiv...
# 1073  University of Michigan About ALEXANDER J. GROE...
# 1355  Dartmouth College; College of William and Mary...
# 1544                                                NaN
# 1877                                                NaN
# 1888    Yale University; Columbia University Law School
# 1987                                                NaN
# 2080                                                NaN
# 2178                                                NaN
# 2211                                   Williams College
# 2260  Richmond College, University of Virginia Law S...
# 2400                                                NaN
# 2423  St. Louis University College of Dentistry; Nor...
#
#                                   birth_state_territory spouse birth_date  \
# 78                                              Georgia    NaN 1944-09-16
# 436                                             Alabama    NaN 1903-09-03
# 794   South Carolina National Office(s) Served Repre...    NaN 1840-01-09
# 812                                           Louisiana    NaN 1987-07-15
# 1067                                           New York    NaN 1959-04-15
# 1073                                           Michigan    NaN 1973-11-07
# 1355                                      New Hampshire    NaN 2011-06-01
# 1544                                           New York    NaN 1943-08-29
# 1877                                       Rhode Island    NaN 1766-02-10
# 1888                                              Other    NaN 1946-08-02
# 1987  South Carolina National Office(s) Served Repre...    NaN 1857-05-15
# 2080                                     North Carolina    NaN 1970-09-23
# 2178                                            Vermont    NaN 1915-01-07
# 2211                                            Vermont    NaN 2020-11-10
# 2260                                           Virginia    NaN        NaT
# 2400                                               Ohio    NaN 1931-12-27
# 2423                                           Illinois    NaN 1943-01-04
#
#                                                bio_text  college_attendance  \
# 78    WILLIAM JAMES SAMFORD was born in Greenville, ...                   1
# 436   HENRY LAURENS MITCHELL, Florida’s 16th governo...                   1
# 794   JOHN ADAIR was born in Chester District, Chest...                   1
# 812   SAM H. JONES was born in Merryville, Louisiana...                   1
# 1067  LUREN D. DICKINSON, the thirty-seventh governo...                   1
# 1073  ALEXANDER J. GROESBECK, the thirtieth governor...                   1
# 1355  WALTER PETERSON was born in Nashua, New Hampsh...                   1
# 1544  DAVID B. HILL, the thirty-second governor of N...                   0
# 1877  HENRY SMITH was born in Providence, Rhode Isla...                   0
# 1888  GEORGE PEABODY WETMORE was born in London, Eng...                   1
# 1987  JAMES HAMILTON JR. was born in Charleston, Sou...                   0
# 2080  WILLIAM TROUSDALE was born in Orange County, N...                   0
# 2178  CHARLES W. GATES was born in Franklin, Vermont...                   0
# 2211  JOHN STANIFORD ROBINSON was born in Bennington...                   1
# 2260  ANDREW JACKSON MONTAGUE was born in Lynchburg,...                   1
# 2400  LUCIUS FAIRCHILD was born in Kent, Ohio, but m...                   0
# 2423  LESTER CALLOWAY HUNT was born in Isabel, Illin...                   1
#
#       ivy_attendance  lawyer  military_service  age_at_start gender  \
# 78                 0       1                 1           NaN   male
# 436                0       1                 1           NaN   male
# 794                0       0                 1           NaN   male
# 812                0       0                 1           NaN   male
# 1067               0       0                 0           NaN   male
# 1073               0       1                 0           NaN   male
# 1355               1       0                 0           NaN   male
# 1544               0       1                 0           NaN   male
# 1877               0       0                 0           NaN   male
# 1888               1       1                 0           NaN   male
# 1987               0       0                 1           NaN   male
# 2080               0       1                 1           NaN   male
# 2178               0       0                 0           NaN   male
# 2211               0       0                 0           NaN   male
# 2260               0       1                 0           NaN   male
# 2400               0       1                 1           NaN   male
# 2423               0       0                 1           NaN   male
#
#       born_in_state_territory  intl_born intl_born_details
# 78                          0          0               NaN
# 436                         0          0               NaN
# 794                         0          0               NaN
# 812                         1          0               NaN
# 1067                        0          0               NaN
# 1073                        1          0               NaN
# 1355                        1          0               NaN
# 1544                        1          0               NaN
# 1877                        1          0               NaN
# 1888                        0          1   London, England
# 1987                        0          0               NaN
# 2080                        0          0               NaN
# 2178                        1          0               NaN
# 2211                        1          0               NaN
# 2260                        1          0               NaN
# 2400                        0          0               NaN
# 2423                        0          0               NaN

# %%
mapping_2 = {'Henry Laurens Mitchell': '1831-09-03',
             'John Adair' : '1757-01-09',
             'Sam Houston Jones' : '1897-07-15',
             'Luren Dudley Dickinson' : '1859-04-15',
             'Alexander Joseph Groesbeck' : '1873-11-07',
             'Walter Peterson' : '1922-09-19',
             'David Bennett Hill' : '1843-08-29',
             'Henry Smith' : '1766-02-10',
             'George Peabody Wetmore': '1846-08-02',
             'William James Samford' : '1844-09-16',
             'James Jr. Hamilton' : '1786-05-08',
             'William Trousdale' : '1790-09-23',
             'Charles W. Gates': '1856-01-12',
             'John Staniford Robinson' : '1804-11-10',
             'Lucius Fairchild' : '1831-12-27',
             'Lester Calloway Hunt' : '1892-07-08'}

df.loc[df['age_at_start'].isna(), 'birth_date'] = (
    df.loc[df['age_at_start'].isna(), 'governor'].map(mapping_2)
)

# Ensure consistent datetime dtype
df['birth_date'] = pd.to_datetime(df['birth_date'], errors='coerce')

# %%
df[df['governor'] == 'Henry Smith']
df['years_in_office'] = np.where(df['governor'] == 'Henry Smith', '1805 - 1806', df['years_in_office'])
df['first_year'] = np.where(df['governor'] == 'Henry Smith', '1805', df['first_year'])

df[df['governor'] == 'George Dewey Clyde']
df['years_in_office'] = np.where(df['governor'] == 'George Dewey Clyde', '1957 - 1965', df['years_in_office'])
df['first_year'] = np.where(df['governor'] == 'George Dewey Clyde', '1957', df['first_year'])

# %%
df['first_year'] = pd.to_numeric(df['first_year'], errors='coerce')
df['new_age_at_start'] = df['first_year'] - df['birth_date'].dt.year

# %%
df[abs(df['new_age_at_start'] - df['age_at_start']) > 1]
# Out:
#       Unnamed: 0 state_territory                 governor       party  \
# 656          657            Iowa        Terry E. Branstad  Republican
# 1141        1142     Mississippi              Phil Bryant  Republican
# 1710        1711            Ohio  Edward Follansbee Noyes  Republican
# 1763        1764          Oregon        John A. Kitzhaber  Democratic
# 2143        2144            Utah       George Dewey Clyde  Republican
# 2359        2360   West Virginia      Henry Mason Mathews  Democratic
#
#       first_year          years_in_office  \
# 656         1983  1983 - 1999 2011 - 2017
# 1141        2012  2012 - 2016 2016 - 2020
# 1710        1832              1872 - 1832
# 1763        1995  1995 - 2003 2011 - 2015
# 2143        1957              1957 - 1965
# 2359        1881              1887 - 1881
#
#                                                  school birth_state_territory  \
# 656     University of Iowa; Drake University Law School                  Iowa
# 1141  Hinds Community College, University of Souther...           Mississippi
# 1710           Dartmouth College, Cincinnati Law School         Massachusetts
# 1763  Dartmouth College, University of Oregon Medica...            Washington
# 2143  Utah State Agricultural College, University of...                  Utah
# 2359                             University of Virginia         West Virginia
#
#                                                  spouse birth_date  ...  \
# 656                                                 NaN 1946-11-17  ...
# 1141  Deborah Bryant Deborah Bryant About Phil Bryan... 1954-12-09  ...
# 1710                                                NaN 1832-10-03  ...
# 1763                                                NaN 1947-03-05  ...
# 2143                                                NaN 1798-07-21  ...
# 2359                                                NaN 1834-03-29  ...
#
#      college_attendance  ivy_attendance  lawyer  military_service  \
# 656                   1               0       1                 1
# 1141                  1               0       0                 0
# 1710                  1               1       1                 1
# 1763                  1               1       0                 0
# 2143                  1               0       0                 0
# 2359                  1               0       0                 1
#
#       age_at_start  gender born_in_state_territory  intl_born  \
# 656           64.0    male                       1          0
# 1141          61.0    male                       1          0
# 1710          39.0    male                       0          0
# 1763          63.0    male                       0          0
# 2143          58.0    male                       1          0
# 2359          52.0    male                       1          0
#
#       intl_born_details new_age_at_start
# 656                 NaN             37.0
# 1141                NaN             58.0
# 1710                NaN              0.0
# 1763                NaN             48.0
# 2143                NaN            159.0
# 2359                NaN             47.0
#
# [6 rows x 21 columns]

# %%
df.loc[df['governor'] == 'George Dewey Clyde', 'birth_date'] = pd.to_datetime('1898-07-21')
df.loc[df['governor'] == 'Isaac Wilbour', 'birth_date'] = pd.to_datetime('1763-04-25')
df.loc[df['governor'] == 'Stevens Thomson Mason', 'birth_date'] = pd.to_datetime('1760-12-29')
df.loc[df['governor'] == 'Amos Walker Barber', 'birth_date'] = pd.to_datetime('1860-07-25')
df.loc[df['governor'] == 'Johnathan Jennings', 'birth_date'] = pd.to_datetime('1784-03-27')
df.loc[df['governor'] == 'Andrew Jackson Montague', 'birth_date'] = pd.to_datetime('1862-10-03')





df['years_in_office'] = np.where(df['governor'] == 'Edward Follansbee Noyes', '1877 - 1881', df['years_in_office'])
df['first_year'] = np.where(df['governor'] == 'Edward Follansbee Noyes', '1877', df['first_year'])
df['first_year'] = pd.to_numeric(df['first_year'], errors='coerce')
df['new_age_at_start'] = df['first_year'] - df['birth_date'].dt.year
df['age_at_start'] = df['new_age_at_start']
df.drop(columns = ['new_age_at_start'], inplace = True)

# %%
df.sort_values('age_at_start')
# Out:
#       Unnamed: 0 state_territory                governor  \
# 833          834       Louisiana      Henry Clay Warmoth
# 522          523         Georgia           George Walton
# 976          977        Maryland            Edward Lloyd
# 1453        1454      New Jersey          Leon R. Taylor
# 2439        2440         Wyoming      Amos Walker Barber
# ...          ...             ...                     ...
# 1101        1102        Michigan   Stevens Thomson Mason
# 1387        1388   New Hampshire           Moody Currier
# 1846        1847    Pennsylvania       Benjamin Franklin
# 1067        1068        Michigan  Luren Dudley Dickinson
# 2380        2381       Wisconsin      Walter S. Goodland
#
#                             party  first_year years_in_office  \
# 833                    Republican        1868     1868 - 1872
# 522   Whig, Democratic-Republican        1779     1779 - 1780
# 976         Democratic-Republican        1809     1809 - 1811
# 1453                   Democratic        1913     1913 - 1914
# 2439                   Republican        1890     1890 - 1893
# ...                           ...         ...             ...
# 1101                   Democratic        1837     1837 - 1840
# 1387                   Republican        1885     1885 - 1887
# 1846                          NaN        1785     1785 - 1788
# 1067                   Republican        1939     1939 - 1941
# 2380                   Republican        1943     1943 - 1947
#
#                                                  school birth_state_territory  \
# 833   system of his native state. He studied law, wa...              Illinois
# 522                                                 NaN              Virginia
# 976                                                 NaN              Maryland
# 1453                                 Denison University            New Jersey
# 2439                         University of Pennsylvania          Pennsylvania
# ...                                                 ...                   ...
# 1101                            Transylvania University              Virginia
# 1387                                  Dartmouth College         New Hampshire
# 1846                                                NaN         Massachusetts
# 1067  in Michigan. Dickinson established an extensiv...              New York
# 2380                                   Lawrence College             Wisconsin
#
#      spouse birth_date                                           bio_text  \
# 833     NaN 1842-05-09  HENRY C. WARMOTH was born in Mc Leansboro, Ill...
# 522     NaN 1749-01-01  GEORGE WALTON, the youngest signer of the Decl...
# 976     NaN 1779-07-22  EDWARD LLOYD was born in Talbot County, Maryla...
# 1453    NaN 1883-10-26  Leon R. Taylor was born in Asbury Park, New Je...
# 2439    NaN 1860-07-25  AMOS WALKER BARBER was born in Doylestown, Pen...
# ...     ...        ...                                                ...
# 1101    NaN 1760-12-29  STEVENS T. MASON, the first governor of Michig...
# 1387    NaN 1806-04-22  MOODY CURRIER, the forty-ninth governor of New...
# 1846    NaN 1706-01-17  Like others among this nation’s Founding Fathe...
# 1067    NaN 1859-04-15  LUREN D. DICKINSON, the thirty-seventh governo...
# 2380    NaN 1862-12-22  WALTER S. GOODLAND was born in Sharon, Wiscons...
#
#       college_attendance  ivy_attendance  lawyer  military_service  \
# 833                    1               0       1                 1
# 522                    0               0       1                 1
# 976                    0               0       0                 1
# 1453                   1               0       0                 0
# 2439                   1               1       0                 1
# ...                  ...             ...     ...               ...
# 1101                   1               0       0                 0
# 1387                   1               1       1                 0
# 1846                   0               0       0                 0
# 1067                   1               0       0                 0
# 2380                   1               0       1                 0
#
#       age_at_start gender  born_in_state_territory  intl_born  \
# 833             26   male                        0          0
# 522             30   male                        0          0
# 976             30   male                        1          0
# 1453            30   male                        1          0
# 2439            30   male                        0          0
# ...            ...    ...                      ...        ...
# 1101            77   male                        0          0
# 1387            79   male                        1          0
# 1846            79   male                        0          0
# 1067            80   male                        0          0
# 2380            81   male                        1          0
#
#      intl_born_details
# 833                NaN
# 522                NaN
# 976                NaN
# 1453               NaN
# 2439               NaN
# ...                ...
# 1101               NaN
# 1387               NaN
# 1846               NaN
# 1067               NaN
# 2380               NaN
#
# [2486 rows x 20 columns]

# %%
df[df['intl_born_details'] == 'Washington, D.C.']


df.loc[df['governor'] == 'John Davis Lodge', 'birth_state_territory'] = 'Washington, D.C.'
df.loc[df['governor'] == 'John Davis Lodge', 'intl_born'] = 0
df.loc[df['governor'] == 'John Davis Lodge', 'intl_born_details'] = np.nan

# %%
df.sort_values(by="school", key=lambda x: x.str.len(), ascending=False)[:100]
# Out:
#       Unnamed: 0 state_territory                   governor  \
# 458          459         Georgia     Lester Garfield Maddox
# 2270        2271        Virginia              William Smith
# 2077        2078       Tennessee             Andrew Johnson
# 497          498         Georgia   George Rockingham Gilmer
# 1353        1354   New Hampshire             Hugh J. Gallen
# ...          ...             ...                        ...
# 1445        1446      New Jersey       Harold Giles Hoffman
# 2210        2211         Vermont              Stephen Royce
# 1164        1165     Mississippi          Edmond Favor Noel
# 975          976        Maryland               Robert Bowie
# 1618        1619  North Carolina  Richard Dobbs Spaight Jr.
#
#                       party  first_year          years_in_office  \
# 458              Democratic        1967              1967 - 1971
# 2270             Democratic        1846  1864 - 1865 1846 - 1849
# 2077             Democratic        1853  1862 - 1865 1853 - 1857
# 497         Democratic-Whig        1829  1837 - 1839 1829 - 1831
# 1353             Democratic        1979              1979 - 1982
# ...                     ...         ...                      ...
# 1445             Republican        1935              1935 - 1938
# 2210       Whig; Republican        1854              1854 - 1856
# 1164             Democratic        1908              1908 - 1912
# 975   Democratic-Republican        1803  1811 - 1812 1803 - 1806
# 1618             Democratic        1835              1835 - 1836
#
#                                                  school birth_state_territory  \
# 458   to pursue odd jobs. Maddox engaged in industri...               Georgia
# 2270  near home, studied privately in Fredericksburg...              Virginia
# 2077  and was eventually taught to read and write by...        North Carolina
# 497   and at the famous Academy of Moses Waddell in ...               Georgia
# 1353  . After graduation, Gallen had a successful tr...                Oregon
# ...                                                 ...                   ...
# 1445  , where he graduated in 1913. During World War...            New Jersey
# 2210  Middlebury College About STEPHEN ROYCE was bor...               Vermont
# 1164  in Louisville, Kentucky. He later studied law,...           Mississippi
# 975   in Prince George’s County and at Reverend Crad...              Maryland
# 1618  University of North Carolina National Office(s...        North Carolina
#
#      spouse birth_date                                           bio_text  \
# 458     NaN 1915-09-30  LESTER GARFIELD MADDOX was born in Atlanta, Ge...
# 2270    NaN 1797-09-06  WILLIAM SMITH was born in Marengo in King Geor...
# 2077    NaN 1808-12-29  Born in Raleigh, North Carolina, ANDREW JOHNSO...
# 497     NaN 1790-04-11  GEORGE ROCKINGHAM GILMER was born near Lexingt...
# 1353    NaN 1924-07-30  HUGH J. GALLEN was born July 30, 1924, in Port...
# ...     ...        ...                                                ...
# 1445    NaN 1896-02-07  Harold G. Hoffman was born in South Amboy, New...
# 2210    NaN 1787-08-12  STEPHEN ROYCE was born in Tinmouth, Vermont. A...
# 1164    NaN 1856-03-04  EDMOND F. NOEL, the thirty-seventh governor of...
# 975     NaN 1750-03-01  ROBERT BOWIE was born at “Mattaponi” in Prince...
# 1618    NaN 1795-12-31  RICHARD D. SPAIGHT, the twenty-seventh governo...
#
#       college_attendance  ivy_attendance  lawyer  military_service  \
# 458                    1               0       1                 0
# 2270                   1               0       1                 1
# 2077                   1               0       1                 0
# 497                    1               0       1                 1
# 1353                   1               0       0                 0
# ...                  ...             ...     ...               ...
# 1445                   1               0       0                 1
# 2210                   1               0       1                 0
# 1164                   1               0       1                 0
# 975                    1               0       0                 1
# 1618                   1               0       1                 0
#
#       age_at_start gender  born_in_state_territory  intl_born  \
# 458             52   male                        1          0
# 2270            49   male                        1          0
# 2077            45   male                        0          0
# 497             39   male                        1          0
# 1353            55   male                        0          0
# ...            ...    ...                      ...        ...
# 1445            39   male                        1          0
# 2210            67   male                        1          0
# 1164            52   male                        1          0
# 975             53   male                        1          0
# 1618            40   male                        1          0
#
#      intl_born_details
# 458                NaN
# 2270               NaN
# 2077               NaN
# 497                NaN
# 1353               NaN
# ...                ...
# 1445               NaN
# 2210               NaN
# 1164               NaN
# 975                NaN
# 1618               NaN
#
# [100 rows x 20 columns]

# %%
def capital_word_ratio(s):
    if not isinstance(s, str) or len(s.strip()) == 0:
        return np.nan
    words = s.split()
    caps = sum(w[0].isupper() for w in words if w)
    return caps / len(words)

df['cap_word_ratio'] = df['school'].apply(capital_word_ratio)

# %%
df.sort_values(by="cap_word_ratio")[:350].to_clipboard()

# %%
df[df['school'].str.contains('and', na=False)].to_clipboard()

# %%
pattern = r"(About [A-Z]+|National Offices? Served?|National Office)"

# Keep only the part before the match
df["school_cleaned"] = df["school"].str.split(pattern, regex=True).str[0].str.strip()

# %%
df['cap_word_ratio'] = df['school_cleaned'].apply(capital_word_ratio)

# %%
df.sort_values(by="cap_word_ratio")[:350].to_clipboard()

# %%
df['school_cleaned'] = np.where(df['cap_word_ratio'] < 0.6, np.nan, df['school_cleaned'])

# %%
school_mapping = {
    'William Paca' : 'College of Philadelphia (now the University of Pennsylvania)',
    'Frank W. Benson' : 'University of the Pacific',
    'Thomas Mifflin' : 'College of Philadelphia (University of Pennsylvania)',
    'Thomas Mann Randolph' : 'College of William and Mary and University of Edinburgh',
    'Matt Meyer' : 'Brown University (BA); University of Michigan (JD)',
    'Thomas Bahnson Stanley': np.nan
}

df['school_cleaned'] = df.apply(
    lambda row: school_mapping.get(row['governor'], row['school_cleaned']), axis=1
)

# %%
df['school'] = df['school_cleaned']
df.drop(columns = ['school_cleaned'], inplace = True)

# %%
df['college_attendance'] = np.where(df['school'].isna(), 0, 1)

# %%
ivy_keywords = [
    "harvard",
    "yale",
    "princeton",
    "columbia",
    "university of pennsylvania",
    "upenn",
    "dartmouth",
    "cornell",
    "brown university"
]

# Make a single regex pattern joining all keywords, ignoring case
ivy_pattern = '|'.join(ivy_keywords)

# Check if 'school_cleaned' contains any of the Ivy keywords
df['ivy_attendance'] = np.where(
    df['school'].str.lower().str.contains(ivy_pattern, regex=True, na=False), 
    1, 
    0
)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'state_territory', 'governor', 'party', 'first_year',
#        'years_in_office', 'school', 'birth_state_territory', 'spouse',
#        'birth_date', 'bio_text', 'college_attendance', 'ivy_attendance',
#        'lawyer', 'military_service', 'age_at_start', 'gender',
#        'born_in_state_territory', 'intl_born', 'intl_born_details',
#        'cap_word_ratio'],
#       dtype='object')

# %%
df = df[['state_territory', 'governor', 'party', 'first_year',
       'years_in_office', 'school', 'birth_state_territory',
       'birth_date', 'bio_text', 'college_attendance', 'ivy_attendance',
       'lawyer', 'military_service', 'age_at_start', 'gender',
       'born_in_state_territory', 'intl_born', 'intl_born_details']]

# %%
df.to_csv('gubernatorial_bios_final.csv')
